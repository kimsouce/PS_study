# %%
from collections import deque
n, m, k, x = map(int, input().split())
queue = deque()
graph = [[] for _ in range(n+1)]
#도로 정보 입력 받기
for _ in range(m):
    a, b = map(int, input().split())
    graph[a].append(b)
#모든 도시에 대한 최단거리 초기화
distance = [-1] * (n+1)
distance[x] = 0 #출발 지점은 0으로 설정
#너비 우선 탐색
queue.append(x)
while queue:
    now = queue.popleft()
    #현재 도시에서 이동할 수 있는 모든도시를 확인
    for next_node in graph[now]:
        if distance[next_node] == -1:
            #최단 거리 갱신
            distance[next_node] = distance[now] + 1
            queue.append(next_node)
check = False
for i in range(1, n+1):
    if distance[i] == k:
        print(i)
        check = True
if check == False:
    print(-1)
# Out:
# 4 4 2 1
# 1 2
# 1 3
# 2 3
# 2 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-da27be02620d> in <module>
#       8     graph[a].append(b)
#       9 #모든 도시에 대한 최단거리 초기화
# ---> 10 distance [-1] * (n+1)
#      11 distance[x] = 0 #출발 지점은 0으로 설정
#      12 #너비 우선 탐색
#
# NameError: name 'distance' is not defined
